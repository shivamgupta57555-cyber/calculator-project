# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns  
df = pd.read_csv("C:\\Users\\acer\\Downloads\VideoGamesProject-main\\VideoGamesProject-main\\VideoGamesSales.csv")
#df.shape[0] # number of rows 
#df.shape[1] # number of columes
#df = df[df.duplicated()]
#df.shape[0]
#df.shape[1]
#df = df.drop_duplicates()
#df.shape[0]
#df.info()
#df["Region"]=df["Region"].fillna("North")
#df=df[df["Region"].isnull()]
#df.shape[0]
#df.head(100)
#df.tail(100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 20
#       6 #df.shape[0] # number of rows
#       7 #df.shape[1] # number of columes
#       8 #df = df[df.duplicated()]
#    (...)     17 #df.head(100)
#      18 #df.tail(100)
#      19 df["NA_Sales"]=df["NA_Sales"].replace("[$]","",regex= True)
# ---> 20 Average_Sales =df["NA_Sales"].mean()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\series.py:6570, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6562 @doc(make_doc("mean", ndim=1))
#    6563 def mean(
#    6564     self,
#    (...)   6568     **kwargs,
#    6569 ):
# -> 6570     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# ...
